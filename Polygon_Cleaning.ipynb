# %%
# !pip install pandas
import pandas as pd
import json
import re
# Out:
# Collecting pandas
#   Downloading pandas-1.3.1-cp37-cp37m-macosx_10_9_x86_64.whl (11.0 MB)
#      |████████████████████████████████| 11.0 MB 2.0 MB/s eta 0:00:01
# Collecting numpy>=1.17.3
#   Downloading numpy-1.21.1-cp37-cp37m-macosx_10_9_x86_64.whl (16.9 MB)
#      |████████████████████████████████| 16.9 MB 4.2 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/derekzhang/miniconda3/lib/python3.7/site-packages (from pandas) (2.8.2)
# Collecting pytz>=2017.3
#   Using cached pytz-2021.1-py2.py3-none-any.whl (510 kB)
# Requirement already satisfied: six>=1.5 in /Users/derekzhang/miniconda3/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Installing collected packages: pytz, numpy, pandas
# Successfully installed numpy-1.21.1 pandas-1.3.1 pytz-2021.1

# %%
df = pd.read_csv("out/polygon.csv")
df.head()
# Out:
#                                                 geom  OBJECTID DFIRM_ID  \
# 0  {"type":"Polygon","coordinates":[[[-118.611324...  27228792   06037C
# 1  {"type":"Polygon","coordinates":[[[-118.623692...  27228793   06037C
# 2  {"type":"Polygon","coordinates":[[[-118.468879...  27228794   06037C
# 3  {"type":"Polygon","coordinates":[[[-118.468983...  27228795   06037C
# 4  {"type":"Polygon","coordinates":[[[-118.611001...  27228796   06037C
#
#   VERSION_ID    FLD_AR_ID                   STUDY_TYP FLD_ZONE  \
# 0    2.3.3.2  06037C_5401  SFHAs WITH HIGH FLOOD RISK       AE
# 1    2.1.1.0  06037C_5402                          NP        X
# 2    2.3.3.2  06037C_5403                          NP        X
# 3    2.3.3.2  06037C_5404                          NP        X
# 4    2.3.3.2  06037C_5405  SFHAs WITH HIGH FLOOD RISK        X
#
#                            ZONE_SUBTY SFHA_TF  STATIC_BFE  ...  VEL_UNIT  \
# 0                                 NaN       T       -9999  ...       NaN
# 1        AREA OF MINIMAL FLOOD HAZARD       F       -9999  ...       NaN
# 2        AREA OF MINIMAL FLOOD HAZARD       F       -9999  ...       NaN
# 3        AREA OF MINIMAL FLOOD HAZARD       F       -9999  ...       NaN
# 4  0.2 PCT ANNUAL CHANCE FLOOD HAZARD       F       -9999  ...       NaN
#
#    AR_REVERT AR_SUBTRV  BFE_REVERT  DEP_REVERT  DUAL_ZONE     SOURCE_CIT  \
# 0        NaN       NaN       -9999       -9999        NaN  06037C_STUDY6
# 1        NaN       NaN       -9999       -9999        NaN  06037C_STUDY1
# 2        NaN       NaN       -9999       -9999        NaN  06037C_STUDY6
# 3        NaN       NaN       -9999       -9999        NaN  06037C_STUDY6
# 4        NaN       NaN       -9999       -9999        NaN  06037C_STUDY6
#
#                                    GFID    SHAPE.STAr  SHAPE.STLe
# 0  390ccb54-2800-448b-a6bd-c8e1fdd855cb  1.896348e-04    0.470740
# 1  390ccb54-2800-448b-a6bd-c8e1fdd855cb  1.331688e-02    1.763406
# 2  390ccb54-2800-448b-a6bd-c8e1fdd855cb  5.491280e-10    0.000176
# 3  390ccb54-2800-448b-a6bd-c8e1fdd855cb  7.194600e-11    0.000089
# 4  390ccb54-2800-448b-a6bd-c8e1fdd855cb  3.592764e-06    0.023899
#
# [5 rows x 24 columns]

# %%
# Empty dataframe
frame = pd.DataFrame({'col': []})

# %%
for i in range(len(df)):
    empty_list = []
    dic = eval(df['geom'][i])
    for j in range(len(dic['coordinates'])):
        coord = dic['coordinates'][j]
        for k in range(len(coord)):
            empty_list.append({'lat': coord[k][1], 'lng': coord[k][0]})
    frame.loc[i] = str(empty_list)

# %%
# Removes ' from the data

frame2 = pd.DataFrame({'col': []})
for i in range(len(frame)):    
    frame2.loc[i] = frame.loc[i][0].replace("'", "")

# %%
frame2.to_csv("CleanedPolygonData.csv")
